# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/294.6 kB ? eta -:--:--
#    ------------ -------------------------- 92.2/294.6 kB 880.9 kB/s eta 0:00:01
#    ------------------- -------------------- 143.4/294.6 kB 1.1 MB/s eta 0:00:01
#    --------------------------------- ------ 245.8/294.6 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.6 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 294.6/294.6 kB 1.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set(rc={'figure.figsize':(8,8)},font_scale=1.3)

# %%
df= pd.read_csv('west_africa_dataset.csv')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15844\2409140379.py:1: DtypeWarning: Columns (6,79,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('west_africa_dataset.csv')

# %%
df
# Out:
#            eventid  iyear  imonth  iday approxdate  extended  resolution  \
# 0     197602130003   1976       2    13        NaN         0         NaN
# 1     197704000001   1977       4     0        NaN         1  12/23/1977
# 2     197705010001   1977       5     1        NaN         0         NaN
# 3     197705010003   1977       5     1        NaN         0         NaN
# 4     197710260001   1977      10    26        NaN         0         NaN
# ...            ...    ...     ...   ...        ...       ...         ...
# 5131  201712290026   2017      12    24        NaN         0         NaN
# 5132  201712300012   2017      12    30        NaN         0         NaN
# 5133  201712300013   2017      12    30        NaN         1         NaN
# 5134  201712300014   2017      12    30        NaN         1         NaN
# 5135  201712300025   2017      12    30        NaN         0         NaN
#
#       country country_txt  region  ...  \
# 0         147     Nigeria      11  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5136 entries, 0 to 5135
# Columns: 135 entries, eventid to related
# dtypes: float64(59), int64(22), object(54)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  5.136000e+03  5136.000000  5136.000000  5136.000000  5136.000000
# mean   2.012063e+11  2011.997664     6.320483    15.458723     0.109618
# std    6.354812e+08     6.356160     3.475396     8.894111     0.312444
# min    1.976021e+11  1976.000000     1.000000     0.000000     0.000000
# 25%    2.012031e+11  2012.000000     3.000000     8.000000     0.000000
# 50%    2.014071e+11  2014.000000     6.000000    15.000000     0.000000
# 75%    2.016021e+11  2016.000000     9.000000    23.000000     0.000000
# max    2.017123e+11  2017.000000    12.000000    31.000000     1.000000
#
#            country  region     latitude    longitude  specificity  ...  \
# count  5136.000000  5136.0  5008.000000  5007.000000  5136.000000  ...
# mean    143.009735    11.0    10.620912     7.239584     1.517523  ...
# std      18.933284     0.0     3.387577     7.050412     0.971094  ...
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended  resolution  \
# 0  197602130003   1976       2    13        NaN         0         NaN
# 1  197704000001   1977       4     0        NaN         1  12/23/1977
# 2  197705010001   1977       5     1        NaN         0         NaN
# 3  197705010003   1977       5     1        NaN         0         NaN
# 4  197710260001   1977      10    26        NaN         0         NaN
#
#    country country_txt  region  ...  \
# 0      147     Nigeria      11  ...
# 1      128  Mauritania      11  ...
# 2      128  Mauritania      11  ...
# 3      128  Mauritania      11  ...
# 4      128  Mauritania      11  ...
#
#                                             addnotes  \
# 0  The victims included Sergeant Adamu Michika, S...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df.sample(5)
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 644   200708280030   2007       8    28        NaN         0        NaN
# 1786  201301230026   2013       1    23        NaN         0        NaN
# 3571  201508110056   2015       8    11        NaN         0        NaN
# 3072  201502010010   2015       2     1        NaN         0        NaN
# 2094  201310240034   2013      10    24        NaN         0        NaN
#
#       country country_txt  region  ...  \
# 644       123        Mali      11  ...
# 1786      147     Nigeria      11  ...
# 3571      147     Nigeria      11  ...
# 3072      147     Nigeria      11  ...
# 2094      147     Nigeria      11  ...
#
#                                                addnotes  \
# 644   The perpetrators were suspected to have kidnap...
# 1786                                                NaN
# 3571                                                NaN
# 3072  Casualty numbers for this incident conflict ac...
# ...

# %%
df.tail()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 5131  201712290026   2017      12    24        NaN         0        NaN
# 5132  201712300012   2017      12    30        NaN         0        NaN
# 5133  201712300013   2017      12    30        NaN         1        NaN
# 5134  201712300014   2017      12    30        NaN         1        NaN
# 5135  201712300025   2017      12    30        NaN         0        NaN
#
#       country country_txt  region  ...  \
# 5131      147     Nigeria      11  ...
# 5132      147     Nigeria      11  ...
# 5133      147     Nigeria      11  ...
# 5134      147     Nigeria      11  ...
# 5135      147     Nigeria      11  ...
#
#                                                addnotes  \
# 5131  Casualty numbers conflict across sources. Foll...
# 5132                                                NaN
# 5133                                                NaN
# 5134                                                NaN
# ...

# %%
df.drop('eventid',axis=1,inplace=True)

# %%
df.shape
# Out:
# (5136, 134)

# %% [markdown]
# ## Analysis and Visualization

# %%
# Checking Null values
df.isnull().sum()
# Out:
# iyear            0
# imonth           0
# iday             0
# approxdate    4950
# extended         0
#               ...
# INT_LOG          0
# INT_IDEO         0
# INT_MISC         0
# INT_ANY          0
# related       3614
# Length: 134, dtype: int64

# %%
#Return Percentage of missing values in each column
for column in df.columns:
    prct_missing = np.mean(df[column].isnull())
    print(f'{column} - {round(prct_missing*100)}%')
# Out:
# iyear - 0%
# imonth - 0%
# iday - 0%
# extended - 0%
# country - 0%
# country_txt - 0%
# region - 0%
# region_txt - 0%
# provstate - 0%
# city - 0%
# latitude - 2%
# longitude - 3%
# specificity - 0%
# vicinity - 0%
# summary - 7%
# crit1 - 0%
# crit2 - 0%
# crit3 - 0%
# doubtterr - 0%
# multiple - 0%
# success - 0%
# suicide - 0%
# attacktype1 - 0%
# attacktype1_txt - 0%
# targtype1 - 0%
# targtype1_txt - 0%
# targsubtype1 - 3%
# targsubtype1_txt - 3%
# corp1 - 6%
# target1 - 0%
# natlty1 - 0%
# natlty1_txt - 0%
# gname - 0%
# guncertain1 - 0%
# individual - 0%
# nperps - 11%
# nperpcap - 9%
# claimed - 7%
# weaptype1 - 0%
# weaptype1_txt - 0%
# weapsubtype1 - 9%
# weapsubtype1_txt - 9%
# nkill - 7%
# nkillus - 7%
# nkillter - 11%
# nwound - 22%
# nwoundus - 8%
# nwoundte - 14%
# property - 0%
# ishostkid - 0%
# scite1 - 7%
# dbsource - 0%
# INT_LOG - 0%
# INT_IDEO - 0%
# INT_MISC - 0%
# INT_ANY - 0%

# %%
# Drop columns that contain 25% or more missing values
for column in df.columns:
    prct_missing = np.mean(df[column].isnull())
    prct_missing = round(prct_missing*100)
    if prct_missing > 25 :
        df.drop([column],axis=1,inplace=True)
        print(f'Droping {column} Column as it contains - {prct_missing}% null values')

# %%
df.shape
# Out:
# (5136, 56)

# %%
# Return the percentage of missing values in each column
for column in df.columns:
    prct_missing = np.mean(df[column].isnull())
    print(f'{column} - {round(prct_missing*100)}%')
# Out:
# iyear - 0%
# imonth - 0%
# iday - 0%
# extended - 0%
# country - 0%
# country_txt - 0%
# region - 0%
# region_txt - 0%
# provstate - 0%
# city - 0%
# latitude - 2%
# longitude - 3%
# specificity - 0%
# vicinity - 0%
# summary - 7%
# crit1 - 0%
# crit2 - 0%
# crit3 - 0%
# doubtterr - 0%
# multiple - 0%
# success - 0%
# suicide - 0%
# attacktype1 - 0%
# attacktype1_txt - 0%
# targtype1 - 0%
# targtype1_txt - 0%
# targsubtype1 - 3%
# targsubtype1_txt - 3%
# corp1 - 6%
# target1 - 0%
# natlty1 - 0%
# natlty1_txt - 0%
# gname - 0%
# guncertain1 - 0%
# individual - 0%
# nperps - 11%
# nperpcap - 9%
# claimed - 7%
# weaptype1 - 0%
# weaptype1_txt - 0%
# weapsubtype1 - 9%
# weapsubtype1_txt - 9%
# nkill - 7%
# nkillus - 7%
# nkillter - 11%
# nwound - 22%
# nwoundus - 8%
# nwoundte - 14%
# property - 0%
# ishostkid - 0%
# scite1 - 7%
# dbsource - 0%
# INT_LOG - 0%
# INT_IDEO - 0%
# INT_MISC - 0%
# INT_ANY - 0%

# %%
df.head()
# Out:
#    iyear  imonth  iday  extended  country country_txt  region  \
# 0   1976       2    13         0      147     Nigeria      11
# 1   1977       4     0         1      128  Mauritania      11
# 2   1977       5     1         0      128  Mauritania      11
# 3   1977       5     1         0      128  Mauritania      11
# 4   1977      10    26         0      128  Mauritania      11
#
#            region_txt      provstate     city  ...  nwoundus  nwoundte  \
# 0  Sub-Saharan Africa          Lagos    Lagos  ...       0.0       0.0
# 1  Sub-Saharan Africa        Unknown  Unknown  ...       NaN       NaN
# 2  Sub-Saharan Africa  Tiris Zemmour  Zouerat  ...       NaN       NaN
# 3  Sub-Saharan Africa  Tiris Zemmour  Zouerat  ...       NaN       NaN
# 4  Sub-Saharan Africa  Tiris Zemmour  Zouerat  ...       NaN       NaN
#
#    property  ishostkid                                             scite1  \
# 0         0        0.0  Segun Akande, "42 years ago, one of Nigeria's ...
# ...

# %%
# unnecessary column collection for the analysis
columns_drop = 'country region attacktype1 targtype1 targsubtype1 natlty1 weaptype1 weapsubtype1'.split()
columns_drop
# Out:
# ['country',
#  'region',
#  'attacktype1',
#  'targtype1',
#  'targsubtype1',
#  'natlty1',
#  'weaptype1',
#  'weapsubtype1']

# %%
df.drop(columns_drop,axis=1,inplace=True)

# %%
df.shape
# Out:
# (5136, 48)

# %% [markdown]
# I start with 135 columns after droping columns that contain 25% null values or more and another columns that aren't important,
# I finally have 48 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5136 entries, 0 to 5135
# Data columns (total 48 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iyear             5136 non-null   int64
#  1   imonth            5136 non-null   int64
#  2   iday              5136 non-null   int64
#  3   extended          5136 non-null   int64
#  4   country_txt       5136 non-null   object
#  5   region_txt        5136 non-null   object
#  6   provstate         5128 non-null   object
#  7   city              5136 non-null   object
#  8   latitude          5008 non-null   float64
#  9   longitude         5007 non-null   float64
#  10  specificity       5136 non-null   float64
#  11  vicinity          5136 non-null   int64
#  12  summary           4756 non-null   object
#  13  crit1             5136 non-null   int64
#  14  crit2             5136 non-null   int64
#  15  crit3             5136 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['iyear', 'imonth', 'iday', 'extended', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'multiple',
#        'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
#        'targsubtype1_txt', 'corp1', 'target1', 'natlty1_txt', 'gname',
#        'guncertain1', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'weaptype1_txt', 'weapsubtype1_txt', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'ishostkid', 'scite1',
#        'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %% [markdown]
# ## Terrorist Incident and Its Success

# %%
sns.countplot(x= df['success'],order=df['success'].value_counts().index)
plt.title('Successed and not Successed Terrorist Incidents',size=20)
plt.show()
